# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("C:/Users/felip/Desktop/correlación adrian/resultados.xlsx", sheet_name="correlacion.py")

# %%
data
# Out:
#     Semanas     0%_v1  0% a 15%_v1  15% a 25%_v1  35% a 45%_v1  45% a 55%_v1  \
# 0         0  0.211336     0.510843      0.739496      0.831169      0.814815
# 1         1  0.139413     0.374718      0.611399      0.707547      0.808219
# 2         2  0.087530     0.295515      0.519651      0.664234      0.729167
# 3         3  0.059873     0.213166      0.404145      0.630058      0.736000
# 4         4  0.038667     0.159170      0.358289      0.513699      0.725191
# 5         5  0.026499     0.114068      0.260116      0.408451      0.682540
# 6         6  0.015759     0.096000      0.167785      0.335766      0.568807
# 7         7  0.014599     0.076613      0.123077      0.244094      0.460000
# 8         8  0.014663     0.062241      0.081301      0.203390      0.382022
# 9         9  0.010401     0.047210      0.080000      0.198198      0.312500
# 10       10  0.010448     0.036199      0.054688      0.134021      0.234568
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data[["Semanas","0%_v2","0% a 15%_v2","15% a 25%_v2"
                 ,"25% a 35%_v2","35% a 45%_v2","45% a 55%_v2",
                 "55% a 65%_v2","65% a 75%_v2","75% a 85%_v2"]].corr(),annot=True,cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data[["Semanas","0%_v3","0% a 15%_v3","15% a 25%_v3"
                 ,"25% a 35%_v3","35% a 45%_v3","45% a 55%_v3",
                 "55% a 65%_v3","65% a 75%_v3","75% a 85%_v3"]].corr(),annot=True,cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data[["Semanas","0%_v4","0% a 15%_v4","15% a 25%_v4"
                 ,"25% a 35%_v4","35% a 45%_v4","45% a 55%_v4",
                 "55% a 65%_v4","65% a 75%_v4","75% a 85%_v4"]].corr(),annot=True,cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
#V4
plt.figure(figsize=(20,2))
sns.heatmap(data[["Semanas","0%_v4","0% a 15%_v4","15% a 25%_v4"
                 ,"25% a 35%_v4","35% a 45%_v4","45% a 55%_v4",
                 "55% a 65%_v4","65% a 75%_v4","75% a 85%_v4"]].corr().iloc[0:1],annot=True,cmap="Blues") # second row of data frame
# Out:
# <AxesSubplot:>

# %%
#v3
plt.figure(figsize=(20,2))
sns.heatmap(data[["Semanas","0%_v3","0% a 15%_v3","15% a 25%_v3"
                 ,"25% a 35%_v3","35% a 45%_v3","45% a 55%_v3",
                 "55% a 65%_v3","65% a 75%_v3","75% a 85%_v3"]].corr().iloc[0:1],annot=True,cmap="Blues") # second row of data frame
# Out:
# <AxesSubplot:>

# %%
#v2
plt.figure(figsize=(20,2))
sns.heatmap(data[["Semanas","0%_v2","0% a 15%_v2","15% a 25%_v2"
                 ,"25% a 35%_v2","35% a 45%_v2","45% a 55%_v2",
                 "55% a 65%_v2","65% a 75%_v2","75% a 85%_v2"]].corr().iloc[0:1],annot=True,cmap="Blues") # second row of data frame
# Out:
# <AxesSubplot:>

# %%
#v1
plt.figure(figsize=(20,2))
sns.heatmap(data[["Semanas","0%_v1","0% a 15%_v1","15% a 25%_v1"
                 ,"35% a 45%_v1","45% a 55%_v1",
                 "55% a 65%_v1","65% a 75%_v1","75% a 85%_v1"]].corr().iloc[0:1],annot=True,cmap="Blues") # second row of data frame
# Out:
# <AxesSubplot:>
